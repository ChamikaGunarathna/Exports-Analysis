# %% [markdown]
# ## Importing Dataset

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
exports_data = pd.read_csv('exports_data.csv')

# %%
exports_data
# Out:
#                                               Product         2006  \
# 0                               Tea Exports (US $ mn)   881.200000
# 1                            Rubber Exports (US $ mn)    93.100000
# 2                           Garment Exports (US $ mn)  2917.038196
# 3   Coconut Production and Exports (by Year, by Co...          NaN
# 4   Coconut Production (mn nuts) (numbers are give...  2785.000000
# 5                           Coconut Exports (mn nuts)   456.000000
# 6                Coconut Exports by Country (US $ mn)          NaN
# 7                                               CHINA     5.925634
# 8                                              U.S.A.     4.609662
# 9                                            PAKISTAN    17.508503
# 10                                              JAPAN     6.696254
# 11                                            GERMANY     5.797748
# 12                                             FRANCE     6.944455
# 13                                        NETHERLANDS     6.962984
# 14                                              EGYPT     6.112196
# 15                                            U.ARB.E    10.962449
# 16                                        SOUTH KOREA     5.478289
# 17                                      SAUDI .ARABIA     3.616825
# 18                                              SPAIN     3.824703
# 19                                     UINTED KINGDOM     3.459103
# 20                                             CANADA     2.771882
# 21                                             MEXICO     0.422575
#
#            2007         2008         2009         2010         2011  \
# 0   1025.000000  1272.000000  1185.306348  1440.620203  1490.898234
# 1    109.100000   124.933400    98.541032   173.179555   206.315040
# 2   3144.665857  3283.799246  3119.552693  3178.397530  3985.753512
# 3           NaN          NaN          NaN          NaN          NaN
# 4   2869.000000  2909.000000  2762.000000  2584.000000  2808.000000
# 5    457.000000   380.373020   366.633741   251.143484   385.727824
# 6           NaN          NaN          NaN          NaN          NaN
# 7      2.891125     1.940562    25.085596    25.590689    30.530753
# 8      5.483234     6.852138     9.182614    14.561573    25.501000
# 9     18.938909    19.120628    14.299351     8.944618    12.444908
# 10     6.056574     5.757597     7.528046     8.259800    11.214383
# 11     6.058493     5.542520     5.710043     7.549955    13.653687
# 12     7.852381     8.309073     7.846780     8.187329    11.795774
# 13     8.849267     9.774441     9.207228     9.710546     8.410759
# 14     6.957378     7.585610     6.339128     6.746458    13.412851
# 15    16.155721    19.121030    13.196595    11.342525    23.848191
# 16     5.788890     5.397589     7.192308     0.469854     7.208938
# 17     3.885895     5.230856     5.581609     4.376661    10.132008
# 18     4.667647     6.090514     4.873882     5.506571    10.762705
# 19     3.392634     3.708987     4.131747     4.931492     6.535574
# 20     2.143867     3.557741     4.486421     4.158445     4.958126
# 21     0.746402     1.294097     1.908218     3.354643     4.402554
#
#            2012
# 0   1411.918700
# 1    125.107677
# 2   3784.294629
# 3           NaN
# 4   2940.000000
# 5    350.694604
# 6           NaN
# 7     27.875159
# 8     20.617392
# 9     13.307071
# 10    11.332678
# 11     9.483488
# 12     9.479003
# 13     8.857434
# 14     8.296073
# 15     7.952844
# 16     7.878868
# 17     7.151892
# 18     7.069498
# 19     7.052243
# 20     6.994817
# 21     5.236265

# %% [markdown]
# Looking at data we can see that coconuts exports are given by country and also by the amount of nuts.
#
# Therefore we can break this into **3 tables**.
#
# 1.  **Tea, Rubber, Garment and Coconuts total exports (US $ mn)**
# 2.  **Coconut Exports by Country (US $ mn)**
# 3.  **Coconut production and exports by amount of nuts (mn nuts)**

# %% [markdown]
# ## Splitting Data set into 3 tables

# %%
total_exports = exports_data.iloc[:3,:].reset_index(drop='index')
ccnut_exp_nut = exports_data.iloc[4:6,:].reset_index(drop='index')
ccnt_exp_country = exports_data.iloc[7:,:].reset_index(drop='index')

# %%
display(total_exports)
display(ccnut_exp_nut)
display(ccnt_exp_country)
# Out:
#                      Product         2006         2007         2008  \
# 0      Tea Exports (US $ mn)   881.200000  1025.000000  1272.000000
# 1   Rubber Exports (US $ mn)    93.100000   109.100000   124.933400
# 2  Garment Exports (US $ mn)  2917.038196  3144.665857  3283.799246
#
#           2009         2010         2011         2012
# 0  1185.306348  1440.620203  1490.898234  1411.918700
# 1    98.541032   173.179555   206.315040   125.107677
# 2  3119.552693  3178.397530  3985.753512  3784.294629
#                                              Product    2006    2007  \
# 0  Coconut Production (mn nuts) (numbers are give...  2785.0  2869.0
# 1                          Coconut Exports (mn nuts)   456.0   457.0
#
#          2008         2009         2010         2011         2012
# 0  2909.00000  2762.000000  2584.000000  2808.000000  2940.000000
# 1   380.37302   366.633741   251.143484   385.727824   350.694604
#            Product       2006       2007       2008       2009       2010  \
# 0            CHINA   5.925634   2.891125   1.940562  25.085596  25.590689
# 1           U.S.A.   4.609662   5.483234   6.852138   9.182614  14.561573
# 2         PAKISTAN  17.508503  18.938909  19.120628  14.299351   8.944618
# 3            JAPAN   6.696254   6.056574   5.757597   7.528046   8.259800
# 4          GERMANY   5.797748   6.058493   5.542520   5.710043   7.549955
# 5           FRANCE   6.944455   7.852381   8.309073   7.846780   8.187329
# 6      NETHERLANDS   6.962984   8.849267   9.774441   9.207228   9.710546
# 7            EGYPT   6.112196   6.957378   7.585610   6.339128   6.746458
# 8          U.ARB.E  10.962449  16.155721  19.121030  13.196595  11.342525
# 9      SOUTH KOREA   5.478289   5.788890   5.397589   7.192308   0.469854
# 10   SAUDI .ARABIA   3.616825   3.885895   5.230856   5.581609   4.376661
# 11           SPAIN   3.824703   4.667647   6.090514   4.873882   5.506571
# 12  UINTED KINGDOM   3.459103   3.392634   3.708987   4.131747   4.931492
# 13          CANADA   2.771882   2.143867   3.557741   4.486421   4.158445
# 14          MEXICO   0.422575   0.746402   1.294097   1.908218   3.354643
#
#          2011       2012
# 0   30.530753  27.875159
# 1   25.501000  20.617392
# 2   12.444908  13.307071
# 3   11.214383  11.332678
# 4   13.653687   9.483488
# 5   11.795774   9.479003
# 6    8.410759   8.857434
# 7   13.412851   8.296073
# 8   23.848191   7.952844
# 9    7.208938   7.878868
# 10  10.132008   7.151892
# 11  10.762705   7.069498
# 12   6.535574   7.052243
# 13   4.958126   6.994817
# 14   4.402554   5.236265

# %% [markdown]
# Getting total coconut exports from **table 3** and adding them to the **table 1**

# %%
ccnt_exp_country.loc[15] = ['total_exports' ]+ list(np.zeros(7))
years = ccnt_exp_country.set_index('Product').columns
for column in years:
    ccnt_exp_country.loc[15, column] = ccnt_exp_country[column].sum()
total_exports_ccnts = ccnt_exp_country.iloc[15:,:].set_index('Product')
total_exports_ccnts.rename(index={'total_exports':'Coconuts Exports (US $ mn)'},inplace=True)
total_exports =total_exports.set_index('Product')
total_exports = pd.concat([total_exports, total_exports_ccnts])

# %%
#total exports table now include the coconut export details too
total_exports
# Out:
#                                    2006         2007         2008  \
# Product
# Tea Exports (US $ mn)        881.200000  1025.000000  1272.000000
# Rubber Exports (US $ mn)      93.100000   109.100000   124.933400
# Garment Exports (US $ mn)   2917.038196  3144.665857  3283.799246
# Coconuts Exports (US $ mn)    91.093263    99.868417   109.283383
#
#                                    2009         2010         2011         2012
# Product
# Tea Exports (US $ mn)       1185.306348  1440.620203  1490.898234  1411.918700
# Rubber Exports (US $ mn)      98.541032   173.179555   206.315040   125.107677
# Garment Exports (US $ mn)   3119.552693  3178.397530  3985.753512  3784.294629
# Coconuts Exports (US $ mn)   126.569566   123.691159   194.812211   158.584725

# %% [markdown]
# ### Analysis - Total Exports

# %%
total_exports
# Out:
#                                    2006         2007         2008  \
# Product
# Tea Exports (US $ mn)        881.200000  1025.000000  1272.000000
# Rubber Exports (US $ mn)      93.100000   109.100000   124.933400
# Garment Exports (US $ mn)   2917.038196  3144.665857  3283.799246
# Coconuts Exports (US $ mn)    91.093263    99.868417   109.283383
#
#                                    2009         2010         2011         2012
# Product
# Tea Exports (US $ mn)       1185.306348  1440.620203  1490.898234  1411.918700
# Rubber Exports (US $ mn)      98.541032   173.179555   206.315040   125.107677
# Garment Exports (US $ mn)   3119.552693  3178.397530  3985.753512  3784.294629
# Coconuts Exports (US $ mn)   126.569566   123.691159   194.812211   158.584725

# %%
years = total_exports.columns
years
# Out:
# Index(['2006', '2007', '2008', '2009', '2010', '2011', '2012'], dtype='object')

# %%
#getting the export values seperately for each sector
tea = total_exports.loc[total_exports.index[0],:].values
rubber = total_exports.loc[total_exports.index[1],:].values
garments = total_exports.loc[total_exports.index[2],:].values
coconuts = total_exports.loc[total_exports.index[3],:].values

# %%
#plotting the exports over the years
x = years
plt.plot(x, tea,color='blue',label='tea')
plt.plot(x, coconuts,color='red',label='coconuts')
plt.plot(x, rubber,color='orange',label='rubber')
plt.plot(x, garments,color='green',label='garments')

plt.xlabel("Years")
plt.ylabel("Exports (US $ mn)")
plt.title('Exports over the years')
plt.legend()

# %%
#plotting exports in each year for each sector for visualization
bins = np.arange(len(years))
width = 0.2 #1/6

plt.figure(figsize=(10,8))
plt.bar(bins,rubber,color='red',width=width,label='Rubber')
plt.bar(bins+width,tea,color='blue',width=width,label='Tea')
plt.bar(bins+2*width,garments,color='green',width=width,label='Garment')
plt.bar(bins+3*width,coconuts,color='yellow',width=width,label='Coconuts')

plt.xlabel("Year") 
plt.ylabel("Exports (US $ mn)") 
plt.title("Exports in each year")

plt.xticks(bins + 1.5*width,years) 
plt.legend()

# %%
#Showing the percentages over the years
total_exports_per = total_exports.copy()
for year in years:
    total_exports_per[year] = (total_exports[year]/total_exports[year].sum())*100
total_exports_per
# Out:
#                                  2006       2007       2008       2009  \
# Product
# Tea Exports (US $ mn)       22.127186  23.409126  26.555235  26.165878
# Rubber Exports (US $ mn)     2.337768   2.491644   2.608204   2.175313
# Garment Exports (US $ mn)   73.247669  71.818418  68.555078  68.864759
# Coconuts Exports (US $ mn)   2.287378   2.280812   2.281483   2.794049
#
#                                  2010       2011       2012
# Product
# Tea Exports (US $ mn)       29.305388  25.364993  25.765383
# Rubber Exports (US $ mn)     3.522854   3.510085   2.283026
# Garment Exports (US $ mn)   64.655607  67.810537  69.057659
# Coconuts Exports (US $ mn)   2.516151   3.314385   2.893932

# %%
#getting average exports pie chart
totat_exports_stats= total_exports_per.transpose()
stats = totat_exports_stats.describe()
total_exports_per['Average'] = stats.mean()
total_exports_per = total_exports_per.reset_index()

labels = 'Tea', 'Rubber', 'Garment', 'Coconut'
sizes = total_exports_per['Average']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e94556d910>,
#   <matplotlib.patches.Wedge at 0x1e945591110>,
#   <matplotlib.patches.Wedge at 0x1e945593350>,
#   <matplotlib.patches.Wedge at 0x1e945592bd0>],
#  [Text(0.7613434579315089, 0.7939497081458577, 'Tea'),
#   Text(-0.17524981742656753, 1.085950045578504, 'Rubber'),
#   Text(-0.759072898999932, -0.7961208036496968, 'Garment'),
#   Text(1.0927063756658324, -0.12646255010571758, 'Coconut')],
#  [Text(0.415278249780823, 0.43306347717046784, '25.67%'),
#   Text(-0.09559080950540046, 0.5923363884973657, '3.76%'),
#   Text(-0.414039763090872, -0.4342477110816528, '66.91%'),
#   Text(0.5960216594540902, -0.06897957278493685, '3.67%')])

# %%
#getting total sums of the exports
total_exports_sum = total_exports.copy()

# %%
total_exp_over_years =[]
for i in range(4):
    total_exp_over_years.append(total_exports_sum.loc[total_exports_sum.index[i],:].values.sum())
total_exp_over_years
# Out:
# [8706.943485, 930.2767041499999, 23413.501663, 903.90272474]

# %%
total_exports_sum['total_over_years'] = total_exp_over_years
total_exports_sum
# Out:
#                                    2006         2007         2008  \
# Product
# Tea Exports (US $ mn)        881.200000  1025.000000  1272.000000
# Rubber Exports (US $ mn)      93.100000   109.100000   124.933400
# Garment Exports (US $ mn)   2917.038196  3144.665857  3283.799246
# Coconuts Exports (US $ mn)    91.093263    99.868417   109.283383
#
#                                    2009         2010         2011  \
# Product
# Tea Exports (US $ mn)       1185.306348  1440.620203  1490.898234
# Rubber Exports (US $ mn)      98.541032   173.179555   206.315040
# Garment Exports (US $ mn)   3119.552693  3178.397530  3985.753512
# Coconuts Exports (US $ mn)   126.569566   123.691159   194.812211
#
#                                    2012  total_over_years
# Product
# Tea Exports (US $ mn)       1411.918700       8706.943485
# Rubber Exports (US $ mn)     125.107677        930.276704
# Garment Exports (US $ mn)   3784.294629      23413.501663
# Coconuts Exports (US $ mn)   158.584725        903.902725

# %%
#tottal exports over 6 years
total_exports_sum['total_over_years'].sum()
# Out:
# 33954.62457689

# %%
#average export over years
total_exports_sum['total_over_years'].sum()/7
# Out:
# 4850.660653841428

# %%
total_exports_sum['total_over_years'].to_list()
# Out:
# [8706.943485, 930.2767041499999, 23413.501663, 903.90272474]

# %%
#Visualizing the Total exports over years for each field
bins = np.arange(4)
width = 0.4

plt.figure(figsize=(10,8))
plt.bar(bins,total_exports_sum['total_over_years'].to_list(),color='blue',width=width)

plt.xlabel("Export Sector") 
plt.ylabel("Exports (US $ mn)") 
plt.title("Overall exports in the Sectors")

plt.xticks(bins,['Tea','Rubber','Garment','Coconuts']) 
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
total_exports_sum['avg_per_year'] = total_exports_sum['total_over_years']/7
total_exports_sum
# Out:
#                                    2006         2007         2008  \
# Product
# Tea Exports (US $ mn)        881.200000  1025.000000  1272.000000
# Rubber Exports (US $ mn)      93.100000   109.100000   124.933400
# Garment Exports (US $ mn)   2917.038196  3144.665857  3283.799246
# Coconuts Exports (US $ mn)    91.093263    99.868417   109.283383
#
#                                    2009         2010         2011  \
# Product
# Tea Exports (US $ mn)       1185.306348  1440.620203  1490.898234
# Rubber Exports (US $ mn)      98.541032   173.179555   206.315040
# Garment Exports (US $ mn)   3119.552693  3178.397530  3985.753512
# Coconuts Exports (US $ mn)   126.569566   123.691159   194.812211
#
#                                    2012  total_over_years  avg_per_year
# Product
# Tea Exports (US $ mn)       1411.918700       8706.943485   1243.849069
# Rubber Exports (US $ mn)     125.107677        930.276704    132.896672
# Garment Exports (US $ mn)   3784.294629      23413.501663   3344.785952
# Coconuts Exports (US $ mn)   158.584725        903.902725    129.128961

# %%
#Pie chart with total exports over the years
labels = 'Tea', 'Rubber', 'Garment', 'Coconut'
sizes = total_exports_sum['total_over_years']

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e945341d50>,
#   <matplotlib.patches.Wedge at 0x1e945320290>,
#   <matplotlib.patches.Wedge at 0x1e945d8fb10>,
#   <matplotlib.patches.Wedge at 0x1e945d9c6d0>],
#  [Text(0.7619506258453026, 0.79336702967413, 'Tea'),
#   Text(-0.13874146670471968, 1.0912152882986121, 'Rubber'),
#   Text(-0.7600124082455014, -0.7952239554445486, 'Garment'),
#   Text(1.0961553605828311, -0.09188811384245332, 'Coconut')],
#  [Text(0.4156094322792559, 0.4327456525495254, '25.64%'),
#   Text(-0.07567716365711981, 0.5952083390719702, '2.74%'),
#   Text(-0.41455222267936437, -0.43375852115157193, '68.96%'),
#   Text(0.5979029239542715, -0.0501207893686109, '2.66%')])

# %% [markdown]
# ### Analyze - Coconuts Exports by Nuts

# %%
ccnut_exp_nut
# Out:
#                                              Product    2006    2007  \
# 0  Coconut Production (mn nuts) (numbers are give...  2785.0  2869.0
# 1                          Coconut Exports (mn nuts)   456.0   457.0
#
#          2008         2009         2010         2011         2012
# 0  2909.00000  2762.000000  2584.000000  2808.000000  2940.000000
# 1   380.37302   366.633741   251.143484   385.727824   350.694604

# %%
ccnut_exp_nut = ccnut_exp_nut.set_index('Product')

# %%
total = []
for i in range(2):
    total.append(ccnut_exp_nut.loc[ccnut_exp_nut.index[i],:].values.sum())
ccnut_exp_nut["total"] = total

# %%
ccnut_exp_nut
# Out:
#                                                       2006    2007  \
# Product
# Coconut Production (mn nuts) (numbers are given...  2785.0  2869.0
# Coconut Exports (mn nuts)                            456.0   457.0
#
#                                                           2008         2009  \
# Product
# Coconut Production (mn nuts) (numbers are given...  2909.00000  2762.000000
# Coconut Exports (mn nuts)                            380.37302   366.633741
#
#                                                            2010         2011  \
# Product
# Coconut Production (mn nuts) (numbers are given...  2584.000000  2808.000000
# Coconut Exports (mn nuts)                            251.143484   385.727824
#
#                                                            2012         total
# Product
# Coconut Production (mn nuts) (numbers are given...  2940.000000  19657.000000
# Coconut Exports (mn nuts)                            350.694604   2647.572673

# %%
print(f"Percentage of Nuts Exported over the years : {(ccnut_exp_nut['total'][1]/ccnut_exp_nut['total'][0])*100}%")
# Out:
# Percentage of Nuts Exported over the years : 13.468854213766088%

# %%
ccnut_stats = ccnut_exp_nut.transpose().describe()
ccnut_stats
# Out:
# Product  Coconut Production (mn nuts) (numbers are given under category 8)  \
# count                                             8.000000
# mean                                           4914.250000
# std                                            5957.979709
# min                                            2584.000000
# 25%                                            2779.250000
# 50%                                            2838.500000
# 75%                                            2916.750000
# max                                           19657.000000
#
# Product  Coconut Exports (mn nuts)
# count                     8.000000
# mean                    661.893168
# std                     804.945000
# min                     251.143484
# 25%                     362.648957
# 50%                     383.050422
# 75%                     456.250000
# max                    2647.572673

# %%
print(f"Average Coconut Production : {round(ccnut_stats.iloc[1][0],6)} mn nuts\nAverage Coconut Exports : {round(ccnut_stats.iloc[1][1],6)} mn nuts")
# Out:
# Average Coconut Production : 4914.25 mn nuts
# Average Coconut Exports : 661.893168 mn nuts

# %%
print(f"Percentage of Export to Production : {(round(round(ccnut_stats.iloc[1][1],6)/ccnut_stats.iloc[1][0],6))*100}%")
# Out:
# Percentage of Export to Production : 13.4689%

# %%
8*0.134689
# Out:
# 1.077512

# %% [markdown]
# ### Analyze - Coconuts Exports by Countries

# %%
ccnt_exp_country
# Out:
#            Product       2006       2007        2008        2009        2010  \
# 0            CHINA   5.925634   2.891125    1.940562   25.085596   25.590689
# 1           U.S.A.   4.609662   5.483234    6.852138    9.182614   14.561573
# 2         PAKISTAN  17.508503  18.938909   19.120628   14.299351    8.944618
# 3            JAPAN   6.696254   6.056574    5.757597    7.528046    8.259800
# 4          GERMANY   5.797748   6.058493    5.542520    5.710043    7.549955
# 5           FRANCE   6.944455   7.852381    8.309073    7.846780    8.187329
# 6      NETHERLANDS   6.962984   8.849267    9.774441    9.207228    9.710546
# 7            EGYPT   6.112196   6.957378    7.585610    6.339128    6.746458
# 8          U.ARB.E  10.962449  16.155721   19.121030   13.196595   11.342525
# 9      SOUTH KOREA   5.478289   5.788890    5.397589    7.192308    0.469854
# 10   SAUDI .ARABIA   3.616825   3.885895    5.230856    5.581609    4.376661
# 11           SPAIN   3.824703   4.667647    6.090514    4.873882    5.506571
# 12  UINTED KINGDOM   3.459103   3.392634    3.708987    4.131747    4.931492
# 13          CANADA   2.771882   2.143867    3.557741    4.486421    4.158445
# 14          MEXICO   0.422575   0.746402    1.294097    1.908218    3.354643
# 15   total_exports  91.093263  99.868417  109.283383  126.569566  123.691159
#
#           2011        2012
# 0    30.530753   27.875159
# 1    25.501000   20.617392
# 2    12.444908   13.307071
# 3    11.214383   11.332678
# 4    13.653687    9.483488
# 5    11.795774    9.479003
# 6     8.410759    8.857434
# 7    13.412851    8.296073
# 8    23.848191    7.952844
# 9     7.208938    7.878868
# 10   10.132008    7.151892
# 11   10.762705    7.069498
# 12    6.535574    7.052243
# 13    4.958126    6.994817
# 14    4.402554    5.236265
# 15  194.812211  158.584725

# %%
ccnt_exp_country.set_index('Product',inplace=True)

# %%
#getting the total exports for each country over the years
total = pd.DataFrame(ccnt_exp_country.sum(axis=1),columns=['total']).reset_index()
total
# Out:
#            Product       total
# 0            CHINA  119.839519
# 1           U.S.A.   86.807613
# 2         PAKISTAN  104.563987
# 3            JAPAN   56.845333
# 4          GERMANY   53.795934
# 5           FRANCE   60.414796
# 6      NETHERLANDS   61.772660
# 7            EGYPT   55.449694
# 8          U.ARB.E  102.579355
# 9      SOUTH KOREA   39.414735
# 10   SAUDI .ARABIA   39.975745
# 11           SPAIN   42.795521
# 12  UINTED KINGDOM   33.211780
# 13          CANADA   29.071299
# 14          MEXICO   17.364754
# 15   total_exports  903.902725

# %%
ccnt_exp_country.reset_index(inplace=True)

# %%
ccnt_exp_country['sum_over_years'] = total['total']
ccnt_exp_country
# Out:
#            Product       2006       2007        2008        2009        2010  \
# 0            CHINA   5.925634   2.891125    1.940562   25.085596   25.590689
# 1           U.S.A.   4.609662   5.483234    6.852138    9.182614   14.561573
# 2         PAKISTAN  17.508503  18.938909   19.120628   14.299351    8.944618
# 3            JAPAN   6.696254   6.056574    5.757597    7.528046    8.259800
# 4          GERMANY   5.797748   6.058493    5.542520    5.710043    7.549955
# 5           FRANCE   6.944455   7.852381    8.309073    7.846780    8.187329
# 6      NETHERLANDS   6.962984   8.849267    9.774441    9.207228    9.710546
# 7            EGYPT   6.112196   6.957378    7.585610    6.339128    6.746458
# 8          U.ARB.E  10.962449  16.155721   19.121030   13.196595   11.342525
# 9      SOUTH KOREA   5.478289   5.788890    5.397589    7.192308    0.469854
# 10   SAUDI .ARABIA   3.616825   3.885895    5.230856    5.581609    4.376661
# 11           SPAIN   3.824703   4.667647    6.090514    4.873882    5.506571
# 12  UINTED KINGDOM   3.459103   3.392634    3.708987    4.131747    4.931492
# 13          CANADA   2.771882   2.143867    3.557741    4.486421    4.158445
# 14          MEXICO   0.422575   0.746402    1.294097    1.908218    3.354643
# 15   total_exports  91.093263  99.868417  109.283383  126.569566  123.691159
#
#           2011        2012  sum_over_years
# 0    30.530753   27.875159      119.839519
# 1    25.501000   20.617392       86.807613
# 2    12.444908   13.307071      104.563987
# 3    11.214383   11.332678       56.845333
# 4    13.653687    9.483488       53.795934
# 5    11.795774    9.479003       60.414796
# 6     8.410759    8.857434       61.772660
# 7    13.412851    8.296073       55.449694
# 8    23.848191    7.952844      102.579355
# 9     7.208938    7.878868       39.414735
# 10   10.132008    7.151892       39.975745
# 11   10.762705    7.069498       42.795521
# 12    6.535574    7.052243       33.211780
# 13    4.958126    6.994817       29.071299
# 14    4.402554    5.236265       17.364754
# 15  194.812211  158.584725      903.902725

# %%
ccnt_exp_country.iloc[:15,:]
# Out:
#            Product       2006       2007       2008       2009       2010  \
# 0            CHINA   5.925634   2.891125   1.940562  25.085596  25.590689
# 1           U.S.A.   4.609662   5.483234   6.852138   9.182614  14.561573
# 2         PAKISTAN  17.508503  18.938909  19.120628  14.299351   8.944618
# 3            JAPAN   6.696254   6.056574   5.757597   7.528046   8.259800
# 4          GERMANY   5.797748   6.058493   5.542520   5.710043   7.549955
# 5           FRANCE   6.944455   7.852381   8.309073   7.846780   8.187329
# 6      NETHERLANDS   6.962984   8.849267   9.774441   9.207228   9.710546
# 7            EGYPT   6.112196   6.957378   7.585610   6.339128   6.746458
# 8          U.ARB.E  10.962449  16.155721  19.121030  13.196595  11.342525
# 9      SOUTH KOREA   5.478289   5.788890   5.397589   7.192308   0.469854
# 10   SAUDI .ARABIA   3.616825   3.885895   5.230856   5.581609   4.376661
# 11           SPAIN   3.824703   4.667647   6.090514   4.873882   5.506571
# 12  UINTED KINGDOM   3.459103   3.392634   3.708987   4.131747   4.931492
# 13          CANADA   2.771882   2.143867   3.557741   4.486421   4.158445
# 14          MEXICO   0.422575   0.746402   1.294097   1.908218   3.354643
#
#          2011       2012  sum_over_years
# 0   30.530753  27.875159      119.839519
# 1   25.501000  20.617392       86.807613
# 2   12.444908  13.307071      104.563987
# 3   11.214383  11.332678       56.845333
# 4   13.653687   9.483488       53.795934
# 5   11.795774   9.479003       60.414796
# 6    8.410759   8.857434       61.772660
# 7   13.412851   8.296073       55.449694
# 8   23.848191   7.952844      102.579355
# 9    7.208938   7.878868       39.414735
# 10  10.132008   7.151892       39.975745
# 11  10.762705   7.069498       42.795521
# 12   6.535574   7.052243       33.211780
# 13   4.958126   6.994817       29.071299
# 14   4.402554   5.236265       17.364754

# %%
#sorted by value
ccnt_exp_country_sorted =ccnt_exp_country.iloc[:15,:].sort_values('sum_over_years')

# %%
#Showing the total exports in a bar chart
plt.figure(figsize=(20,8))
#plt.bar(x='Product',height='sum_over_years',data=ccnt_exp_country.iloc[:15,:].sort_values('sum_over_years'))
plt.barh(y='Product',width='sum_over_years',data=ccnt_exp_country_sorted)
plt.xlabel("Exports (US $ mn)") 
plt.ylabel("Countries") 
plt.title("Coconut Exports by Country")
# Out:
# Text(0.5, 1.0, 'Coconut Exports by Country')

# %%
#5 top countries
ccnt_exp_country_sorted = ccnt_exp_country_sorted.sort_values('sum_over_years',ascending=False)
ccnt_exp_country_sorted.head(5)
# Out:
#        Product       2006       2007       2008       2009       2010  \
# 0        CHINA   5.925634   2.891125   1.940562  25.085596  25.590689
# 2     PAKISTAN  17.508503  18.938909  19.120628  14.299351   8.944618
# 8      U.ARB.E  10.962449  16.155721  19.121030  13.196595  11.342525
# 1       U.S.A.   4.609662   5.483234   6.852138   9.182614  14.561573
# 6  NETHERLANDS   6.962984   8.849267   9.774441   9.207228   9.710546
#
#         2011       2012  sum_over_years
# 0  30.530753  27.875159      119.839519
# 2  12.444908  13.307071      104.563987
# 8  23.848191   7.952844      102.579355
# 1  25.501000  20.617392       86.807613
# 6   8.410759   8.857434       61.772660

# %%
ccnt_exp_country_sorted['Average'] = (ccnt_exp_country_sorted['sum_over_years']/ccnt_exp_country_sorted['sum_over_years'].sum())*100
ccnt_exp_country_sorted
# Out:
#            Product       2006       2007       2008       2009       2010  \
# 0            CHINA   5.925634   2.891125   1.940562  25.085596  25.590689
# 2         PAKISTAN  17.508503  18.938909  19.120628  14.299351   8.944618
# 8          U.ARB.E  10.962449  16.155721  19.121030  13.196595  11.342525
# 1           U.S.A.   4.609662   5.483234   6.852138   9.182614  14.561573
# 6      NETHERLANDS   6.962984   8.849267   9.774441   9.207228   9.710546
# 5           FRANCE   6.944455   7.852381   8.309073   7.846780   8.187329
# 3            JAPAN   6.696254   6.056574   5.757597   7.528046   8.259800
# 7            EGYPT   6.112196   6.957378   7.585610   6.339128   6.746458
# 4          GERMANY   5.797748   6.058493   5.542520   5.710043   7.549955
# 11           SPAIN   3.824703   4.667647   6.090514   4.873882   5.506571
# 10   SAUDI .ARABIA   3.616825   3.885895   5.230856   5.581609   4.376661
# 9      SOUTH KOREA   5.478289   5.788890   5.397589   7.192308   0.469854
# 12  UINTED KINGDOM   3.459103   3.392634   3.708987   4.131747   4.931492
# 13          CANADA   2.771882   2.143867   3.557741   4.486421   4.158445
# 14          MEXICO   0.422575   0.746402   1.294097   1.908218   3.354643
#
#          2011       2012  sum_over_years    Average
# 0   30.530753  27.875159      119.839519  13.258011
# 2   12.444908  13.307071      104.563987  11.568058
# 8   23.848191   7.952844      102.579355  11.348495
# 1   25.501000  20.617392       86.807613   9.603645
# 6    8.410759   8.857434       61.772660   6.833994
# 5   11.795774   9.479003       60.414796   6.683772
# 3   11.214383  11.332678       56.845333   6.288877
# 7   13.412851   8.296073       55.449694   6.134476
# 4   13.653687   9.483488       53.795934   5.951518
# 11  10.762705   7.069498       42.795521   4.734527
# 10  10.132008   7.151892       39.975745   4.422572
# 9    7.208938   7.878868       39.414735   4.360506
# 12   6.535574   7.052243       33.211780   3.674265
# 13   4.958126   6.994817       29.071299   3.216198
# 14   4.402554   5.236265       17.364754   1.921087

# %%
average_ = ccnt_exp_country_sorted[['Product','Average']]

# %%
#showing the total exports by percentage
fig, ax = plt.subplots(figsize=(25,10))

bars = ax.bar(x='Product',height='Average',data=average_)
#bars = ax.barh(y='Product',width='Average',data=average_)
ax.bar_label(bars,labels=[f'{x:,.2f}%' for x in bars.datavalues])
plt.xlabel("Countries")
plt.ylabel("Average Exports") 
plt.title("Coconut Average Exports by Country")
# Out:
# Text(0.5, 1.0, 'Coconut Average Exports by Country')

# %%
average_.head(5)
# Out:
#        Product    Average
# 0        CHINA  13.258011
# 2     PAKISTAN  11.568058
# 8      U.ARB.E  11.348495
# 1       U.S.A.   9.603645
# 6  NETHERLANDS   6.833994

# %%
#saving the average values
average_.to_csv("export_by_countries.csv")
